# %% [markdown]
# 1. Write a program which will find all such numbers which are divisible by 7 but are not a
# multiple of 5, between 2000 and 3200 (both included). The numbers obtained should be printed
# in a comma-separated sequence on a single line

# %%
x = range(2000, 3201)
a;
for n in x:
  if n%5==0:
    if n%7!=0:
        print(n)
# Out:
# 2000
# 2005
# 2010
# 2015
# 2020
# 2025
# 2035
# 2040
# 2045
# 2050
# 2055
# 2060
# 2070
# 2075
# 2080
# 2085
# 2090
# 2095
# 2105
# 2110
# 2115
# 2120
# 2125
# 2130
# 2140
# 2145
# 2150
# 2155
# 2160
# 2165
# 2175
# 2180
# 2185
# 2190
# 2195
# 2200
# 2210
# 2215
# 2220
# 2225
# 2230
# 2235
# 2245
# 2250
# 2255
# 2260
# 2265
# 2270
# 2280
# 2285
# 2290
# 2295
# 2300
# 2305
# 2315
# 2320
# 2325
# 2330
# 2335
# 2340
# 2350
# 2355
# 2360
# 2365
# 2370
# 2375
# 2385
# 2390
# 2395
# 2400
# 2405
# 2410
# 2420
# 2425
# 2430
# 2435
# 2440
# 2445
# 2455
# 2460
# 2465
# 2470
# 2475
# 2480
# 2490
# 2495
# 2500
# 2505
# 2510
# 2515
# 2525
# 2530
# 2535
# 2540
# 2545
# 2550
# 2560
# 2565
# 2570
# 2575
# 2580
# 2585
# 2595
# 2600
# 2605
# 2610
# 2615
# 2620
# 2630
# 2635
# 2640
# 2645
# 2650
# 2655
# 2665
# 2670
# 2675
# 2680
# 2685
# 2690
# 2700
# 2705
# 2710
# 2715
# 2720
# 2725
# 2735
# 2740
# 2745
# 2750
# 2755
# 2760
# 2770
# 2775
# 2780
# 2785
# 2790
# 2795
# 2805
# 2810
# 2815
# 2820
# 2825
# 2830
# 2840
# 2845
# 2850
# 2855
# 2860
# 2865
# 2875
# 2880
# 2885
# 2890
# 2895
# 2900
# 2910
# 2915
# 2920
# 2925
# 2930
# 2935
# 2945
# 2950
# 2955
# 2960
# 2965
# 2970
# 2980
# 2985
# 2990
# 2995
# 3000
# 3005
# 3015
# 3020
# 3025
# 3030
# 3035
# 3040
# 3050
# 3055
# 3060
# 3065
# 3070
# 3075
# 3085
# 3090
# 3095
# 3100
# 3105
# 3110
# 3120
# 3125
# 3130
# 3135
# 3140
# 3145
# 3155
# 3160
# 3165
# 3170
# 3175
# 3180
# 3190
# 3195
# 3200

# %%
# Out:
# [2000,
#  2005,
#  2010,
#  2015,
#  2020,
#  2025,
#  2035,
#  2040,
#  2045,
#  2050,
#  2055,
#  2060,
#  2070,
#  2075,
#  2080,
#  2085,
#  2090,
#  2095,
#  2105,
#  2110,
#  2115,
#  2120,
#  2125,
#  2130,
#  2140,
#  2145,
#  2150,
#  2155,
#  2160,
#  2165,
#  2175,
#  2180,
#  2185,
#  2190,
#  2195,
#  2200,
#  2210,
#  2215,
#  2220,
#  2225,
#  2230,
#  2235,
#  2245,
#  2250,
#  2255,
#  2260,
#  2265,
#  2270,
#  2280,
#  2285,
#  2290,
#  2295,
#  2300,
#  2305,
#  2315,
#  2320,
#  2325,
#  2330,
#  2335,
#  2340,
#  2350,
#  2355,
#  2360,
#  2365,
#  2370,
#  2375,
#  2385,
#  2390,
#  2395,
#  2400,
#  2405,
#  2410,
#  2420,
#  2425,
#  2430,
#  2435,
#  2440,
#  2445,
#  2455,
#  2460,
#  2465,
#  2470,
#  2475,
#  2480,
#  2490,
#  2495,
#  2500,
#  2505,
#  2510,
#  2515,
#  2525,
#  2530,
#  2535,
#  2540,
#  2545,
#  2550,
#  2560,
#  2565,
#  2570,
#  2575,
#  2580,
#  2585,
#  2595,
#  2600,
#  2605,
#  2610,
#  2615,
#  2620,
#  2630,
#  2635,
#  2640,
#  2645,
#  2650,
#  2655,
#  2665,
#  2670,
#  2675,
#  2680,
#  2685,
#  2690,
#  2700,
#  2705,
#  2710,
#  2715,
#  2720,
#  2725,
#  2735,
#  2740,
#  2745,
#  2750,
#  2755,
#  2760,
#  2770,
#  2775,
#  2780,
#  2785,
#  2790,
#  2795,
#  2805,
#  2810,
#  2815,
#  2820,
#  2825,
#  2830,
#  2840,
#  2845,
#  2850,
#  2855,
#  2860,
#  2865,
#  2875,
#  2880,
#  2885,
#  2890,
#  2895,
#  2900,
#  2910,
#  2915,
#  2920,
#  2925,
#  2930,
#  2935,
#  2945,
#  2950,
#  2955,
#  2960,
#  2965,
#  2970,
#  2980,
#  2985,
#  2990,
#  2995,
#  3000,
#  3005,
#  3015,
#  3020,
#  3025,
#  3030,
#  3035,
#  3040,
#  3050,
#  3055,
#  3060,
#  3065,
#  3070,
#  3075,
#  3085,
#  3090,
#  3095,
#  3100,
#  3105,
#  3110,
#  3120,
#  3125,
#  3130,
#  3135,
#  3140,
#  3145,
#  3155,
#  3160,
#  3165,
#  3170,
#  3175,
#  3180,
#  3190,
#  3195,
#  3200]

# %% [markdown]
# 2. Write a Python program to accept the user's first and last name and then getting them
# printed in the the reverse order with a space between first name and last name.

# %%
firstname = input("Input your First Name : ")
lastname = input("Input your Last Name : ")
lastname=lastname[::-1]
firstname=firstname[::-1]
print ("Hello  "+firstname +" " + lastname)
# Out:
# Input your First Name : Santosh
# Input your Last Name : Sankannavar
# Hello  hsotnaS ravannaknaS

# %% [markdown]
# 3.Write a Python program to find the volume of a sphere with diameter 12 cm.

# %%
d = float(input('Enter diameter: '))  
   
volume = (4 * 22 * ((d/2) ** 3))/(3 * 7) 

print("The volume is:", round(volume,2))
# Out:
# Enter diameter: 12
# The volume is: 905.14
